# %% [markdown]
# # Nolan Kiel
# ## Week 16 - 05/3/22
# ### Python - Data Visualization

# %%
import numpy as np
from numpy.random import randn
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

#tickets, labels, and egends
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(randn(1000).cumsum())

# %%
ax.set_xticks([0,250,500,750,1000])
ax.set_xticklabels(['one','two','three','four','five'], rotation=30,fontsize='small')
ax.set_title('My Matplotlb plot with ticks')
ax.set_xlabel('stages')
ax.set_ylabel('Values')

fig

# %%
props = {'title': 'My first Matplotlip plot with ticks',
        'xlabel': 'stages',
        'ylabel': 'Values'}

ax.set(**props)
fig

# %%
fig = plt.figure()
ax=fig.add_subplot(1,1,1)

ax.plot(randn(1000).cumsum(), 'ko-', label= 'one')
ax.plot(randn(1000),cumsum(), 'g--', label= 'two')
ax.plot(randn(1000),sumsum(), 'y.', label = 'three')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2318f0ead6b9> in <module>
#       3
#       4 ax.plot(randn(1000).cumsum(), 'ko-', label= 'one')
# ----> 5 ax.plot(randn(1000),cumsum(), 'g--', label= 'two')
#       6 ax.plot(randn(1000),sumsum(), 'y.', label = 'three')
#       7
#
# NameError: name 'cumsum' is not defined

# %%
#saving a figure ina n image file
fig.savefig('fig1.png')
